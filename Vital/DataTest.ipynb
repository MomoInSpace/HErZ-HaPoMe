# %%
#import numpy as np
#import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
#from datetime import datetime
import xarray as xr
import numpy as np

# %%
from import_DAT import get_data_from_dat_file
from import_DAT import get_data_from_folder

# %%
dat1_complete = get_data_from_folder("GEC_CL51_Testfiles")

# %%
dat2_complete = get_data_from_folder("WMH_CL51_Testfiles")

# %%
dat1_complete
# Out:
# <xarray.DataArray (meter: 1540, time: 7200)>
# array([[3.55534806, 3.66356165, 3.93182563, ..., 4.18965474, 4.15888308,
#         4.17438727],
#        [3.55534806, 3.66356165, 3.78418963, ..., 4.07753744, 4.07753744,
#         4.09434456],
#        [3.58351894, 3.58351894, 3.61091791, ..., 3.97029191, 4.02535169,
#         4.04305127],
#        ...,
#        [       nan,        nan,        nan, ..., 7.24636808,        nan,
#         6.14203741],
#        [4.20469262,        nan,        nan, ..., 7.22693602,        nan,
#         6.3044488 ],
#        [0.        , 0.        , 0.        , ..., 0.        , 0.        ,
#         0.        ]])
# Coordinates:
#   * meter    (meter) int64 0 10 20 30 40 50 ... 15350 15360 15370 15380 15390
#   * time     (time) datetime64[ns] 2024-03-29T00:00:31 ... 2024-03-31T23:59:58

# %%
plt.figure().set_figwidth(45)
dat1_complete.plot(cmap = "jet")

plt.savefig("plots/GEC_PLot1.png") #levels = np.arange(0,7,0.5))

# %%
plt.figure().set_figwidth(45)
dat1_complete.plot(cmap = "jet",levels = np.arange(0,7,0.5))

#plt.savefig("plots/GEC_PLot2.png") #levels = np.arange(0,7,0.5))

# %%
plt.figure().set_figwidth(45)
dat1_complete[:400,:].plot(cmap = "jet",levels = np.arange(0,7,0.5))

#plt.savefig("plots/GEC_PLot3.png") #levels = np.arange(0,7,0.5))

# %%
plt.figure().set_figwidth(45)
dat1_complete[:200,3600:5200].plot(cmap = "jet",levels = np.arange(0,7,0.5))
#plt.savefig("plots/GEC_PLot4.png")
